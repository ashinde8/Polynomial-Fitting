# %% [markdown]
# # Ashutosh Shinde

# %% [markdown]
# # 1) Plotted the noisy data and the polynomial in the same figure. The values of m are selected from 2, 3, 4, 5, 6

# %% [markdown]
# Here I practically implemented the polynomial fitting. I also visualized the effect of the magnitude of noise and number of samples on the accuracy of the plotted function by tuning the parameters. I have used the polyfit() function provided by the numpy package.
# The polynomial used is y = 5 * x + 20 * x * 2 + x * 3.
# I deployed the Matplotlib library package for plotting our findings using the pyplot function.
# (Matplotlib is a python library that provides a MALTLAB like interface using a set of functions similar to MATLAB)
# Numpy will be used to carry out the calculation of the mathematical function.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def x_y_values(noise_scale, number_of_samples):
    x = 25*(np.random.rand(number_of_samples, 1) - 0.8)
    y = 5 * x + 20 * x**2 + 1 * x**3 + noise_scale*np.random.randn(number_of_samples, 1)
    return x, y

# %%
def func_polynomial(noise_scale, number_of_samples, m):
    
    #x = 25*(np.random.rand(number_of_samples, 1) - 0.8)
    #y = 5 * x + 20 * x**2 + 1 * x**3 + noise_scale*np.random.randn(number_of_samples, 1)
    x, y = x_y_values(noise_scale, number_of_samples)
    
    plt.style.use('seaborn-whitegrid')
    plt.plot(x,y,'ro')
 
    print("type of x is:", type(x))
    print("type of y is:", type(y))
    
    x = x.flatten()
    y = y.flatten()
    
    coef = np.polyfit(x,y,m)
    print("Coefficients for the polynomial are:", coef)
    
    y_calculated = []
    
    fig = np.poly1d(coef)
    xl = np.linspace(-20,5,50)
    plt.plot(x,y,'ro',xl,fig(xl),'g')
    plt.show()
    
    for i in range(len(x)):
        y_new = fig(x[i])
        y_calculated.append(y_new)
    
    mean_sqr_error = np.square(np.subtract(y,y_calculated)).mean() 
    print("The mean square error is:", mean_sqr_error)
    return mean_sqr_error

# %% [markdown]
# Here I have plotted the noisy data and also the polynomials for m = 1 to m = 8

# %%
mse1 = func_polynomial(100,50,1)
# Out:
# type of x is: <class 'numpy.ndarray'>
# type of y is: <class 'numpy.ndarray'>
# Coefficients for the polynomial are: [-31.49031403 250.07736329]
# The mean square error is: 108372.45084693906

# %%
mse2 = func_polynomial(100,50,2)
# Out:
# type of x is: <class 'numpy.ndarray'>
# type of y is: <class 'numpy.ndarray'>
# Coefficients for the polynomial are: [ -3.2324474  -96.53982184  44.914407  ]
# The mean square error is: 56537.75434400355

# %%
#m=3
mse3 = func_polynomial(100,50,3)
# Out:
# type of x is: <class 'numpy.ndarray'>
# type of y is: <class 'numpy.ndarray'>
# Coefficients for the polynomial are: [ 0.93304101 18.82018124  6.79004931 28.0116761 ]
# The mean square error is: 10057.661456302287

# %%
#m=4
mse4 = func_polynomial(100,50,4)
# Out:
# type of x is: <class 'numpy.ndarray'>
# type of y is: <class 'numpy.ndarray'>
# Coefficients for the polynomial are: [ 1.51300982e-02  1.40919882e+00  2.24775484e+01  2.85202808e+00
#  -6.89559305e+00]
# The mean square error is: 7360.641307654263

# %%
#m=5
mse5 = func_polynomial(100,50,5)
# Out:
# type of x is: <class 'numpy.ndarray'>
# type of y is: <class 'numpy.ndarray'>
# Coefficients for the polynomial are: [ 1.08829418e-03  2.60928765e-02  1.00658736e+00  1.73588213e+01
#  -6.08959608e+00  1.17546114e+01]
# The mean square error is: 9570.822797163006

# %%
#m=6
mse6 = func_polynomial(100,50,6)
# Out:
# type of x is: <class 'numpy.ndarray'>
# type of y is: <class 'numpy.ndarray'>
# Coefficients for the polynomial are: [ 4.59839496e-04  2.22895929e-02  3.40732469e-01  2.35574397e+00
#   1.38739255e+01 -2.68920526e+01  3.91526508e+00]
# The mean square error is: 5788.05923134297

# %%
mse7 = func_polynomial(100,50,7)
# Out:
# type of x is: <class 'numpy.ndarray'>
# type of y is: <class 'numpy.ndarray'>
# Coefficients for the polynomial are: [ 2.27597320e-05  1.34225046e-03  2.89283317e-02  2.57159532e-01
#   1.41314958e+00  1.35280547e+01 -1.78279675e+01  3.38184448e+01]
# The mean square error is: 6929.156239035168

# %%
mse8 = func_polynomial(100,50,8)
# Out:
# type of x is: <class 'numpy.ndarray'>
# type of y is: <class 'numpy.ndarray'>
# Coefficients for the polynomial are: [-8.51446968e-06 -5.09986137e-04 -1.08061783e-02 -8.64064846e-02
#   1.63392481e-04  3.80403881e+00  2.52690489e+01 -1.93966011e+01
#  -4.34723786e+01]
# The mean square error is: 8978.949830938791

# %% [markdown]
# # 2) Plotted MSE versus order m, for m = 1, 2, 3, 4, 5, 6, 7, 8. Identified the best choice of order m

# %%
MSE = [mse1,mse2,mse3,mse4,mse5,mse6,mse7,mse8]
print("The MSE values for the different m values are:", MSE)
# Out:
# The MSE values for the different m values are: [108372.45084693906, 56537.75434400355, 10057.661456302287, 7360.641307654263, 9570.822797163006, 5788.05923134297, 6929.156239035168, 8978.949830938791]

# %%
print("The least MSE value is :", min(MSE))
# Out:
# The least MSE value is : 5788.05923134297

# %% [markdown]
# We see above that the least MSE value is when m = 6
# with the The mean square error of 5788.05923134297

# %%
m_val = [1,2,3,4,5,6,7,8]
plt.plot(m_val,MSE,'-bo')
plt.xlabel("M values")
plt.ylabel("MSE Values")
# Out:
# Text(0, 0.5, 'MSE Values')

# %% [markdown]
# As we can see from the above line graph the value of m for which the MSE value is the minimum is for m =6

# %% [markdown]
# # 3) Changed the variable noise_scale to 150, 200, 400, 600, 1000 respectively, re-ran the algorithm and plotted the polynomials with the m found in 2). Described the impact of noise scale to the accuracy of the returned parameters.

# %%
Here I have called the function "func_polynomial" by increasing the noise_scale from 150 to 1000.

# %%
func_polynomial(150,50,6)
# Out:
# type of x is: <class 'numpy.ndarray'>
# type of y is: <class 'numpy.ndarray'>
# Coefficients for the polynomial are: [-8.44142353e-04 -3.52089144e-02 -4.65024329e-01 -7.76094602e-01
#   2.33674268e+01  2.91653931e+01  1.26383831e+01]
# The mean square error is: 19506.07256591041
# 19506.07256591041

# %%
func_polynomial(200,50,6)
# Out:
# type of x is: <class 'numpy.ndarray'>
# type of y is: <class 'numpy.ndarray'>
# Coefficients for the polynomial are: [ 6.45733974e-04  3.22474670e-02  5.18535491e-01  3.29504658e+00
#   1.08957121e+01 -4.14071127e+01  7.43332580e+01]
# The mean square error is: 40110.76264639831
# 40110.76264639831

# %%
func_polynomial(400,50,6)
# Out:
# type of x is: <class 'numpy.ndarray'>
# type of y is: <class 'numpy.ndarray'>
# Coefficients for the polynomial are: [ 2.26514418e-04  7.99755809e-03  2.27751397e-02 -2.56020225e-01
#   1.55761692e+01  5.40007019e+01  4.02242585e+01]
# The mean square error is: 150164.5239029233
# 150164.5239029233

# %%
func_polynomial(600,50,6)
# Out:
# type of x is: <class 'numpy.ndarray'>
# type of y is: <class 'numpy.ndarray'>
# Coefficients for the polynomial are: [7.74006610e-04 3.39834318e-02 4.08192408e-01 1.06966772e+00
#  4.94515178e+00 2.84007000e+01 1.95147621e+02]
# The mean square error is: 278980.2579660734
# 278980.2579660734

# %%
func_polynomial(1000,50,6)
# Out:
# type of x is: <class 'numpy.ndarray'>
# type of y is: <class 'numpy.ndarray'>
# Coefficients for the polynomial are: [ 7.07163086e-04  3.17623983e-02  4.41916102e-01  1.58713108e+00
#  -1.16688154e+01 -1.53606757e+02  1.01892322e+02]
# The mean square error is: 820127.988980341
# 820127.988980341

# %% [markdown]
# # Here I observed that as the noise increased, the points dispersed more and the the polynomial function plotted lost its accuracy. Due to an increase in the oscillation of data, the polynomial function failed to identify the nature of the data provided. With an increase in <TT>noise_scale</TT>, the function first widened(with respect to the orignal) and then took another form to fit most of the data, however inaccurately.

# %% [markdown]
# # 4) Here I changed the variable, number_of_samples to 40, 30, 20, 10 respectively, re-ran the algorithm and plotted the polynomials with the m found in 2). Described the impact of the number of samples to the accuracy of the returned parameters.

# %%
func_polynomial(100,40,6)
# Out:
# type of x is: <class 'numpy.ndarray'>
# type of y is: <class 'numpy.ndarray'>
# Coefficients for the polynomial are: [-2.94177393e-04 -1.27106592e-02 -1.64477651e-01  7.94516417e-01
#   2.76828700e+01  2.96372580e+01 -1.79705133e+01]
# The mean square error is: 9973.22385981677
# 9973.22385981677

# %%
func_polynomial(100,30,6)
# Out:
# type of x is: <class 'numpy.ndarray'>
# type of y is: <class 'numpy.ndarray'>
# Coefficients for the polynomial are: [-1.39475979e-04 -7.26623349e-03 -1.19611568e-01  5.08816592e-01
#   2.28689701e+01  1.93317369e+01  8.50327977e+00]
# The mean square error is: 7441.987086453069
# 7441.987086453069

# %%
func_polynomial(100,20,6)
# Out:
# type of x is: <class 'numpy.ndarray'>
# type of y is: <class 'numpy.ndarray'>
# Coefficients for the polynomial are: [-9.25584838e-07 -9.29348531e-04 -4.10607839e-02  4.26203001e-01
#   1.85382521e+01  2.21993173e+01  2.62221558e+00]
# The mean square error is: 4382.516230219957
# 4382.516230219957

# %%
func_polynomial(100,10,6)
# Out:
# type of x is: <class 'numpy.ndarray'>
# type of y is: <class 'numpy.ndarray'>
# Coefficients for the polynomial are: [-1.02669246e-03 -3.28998527e-02 -2.08508471e-01  3.16725494e+00
#   4.22825568e+01  1.94168787e+01 -2.38874731e+01]
# The mean square error is: 546.7604962499487
# 546.7604962499487

# %% [markdown]
# # The polynomial function has less data to train and the polynomial function starts to lose its accuracy as the number of samples decrease. We observed that with a decrease in the number of samples there was also a decrease in the variety of data available that reflected the true nature of the data. It can be observed that when sample size started to decrease, the polynomial function varied from the original data because the function hasn't learnt enough.
